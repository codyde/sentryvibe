# %% [markdown]
# # Single-View Build Flow
#
# 1. **Remove Tab Structure**
#    - Delete `BuildChatTabs` usage (and supporting state) in `apps/sentryvibe/src/app/page.tsx`.
#    - Drop `BuildMessageStream` references so we rely on the Build (todo) view only.
#
# 2. **Conversation Recap Section**
#    - Render the initial user request (`displayedInitialMessage` fallback) and the agent’s build-plan response (markdown) in lightweight cards above the build UI.
#    - Keep styling minimal, reuse existing `ChatUpdate` + `ReactMarkdown` formatting for consistency.
#
# 3. **Thinking + Todo Flow**
#    - Show a “Thinking” indicator (with optional project metadata card) whenever `generationState` is active but `todos` are not yet populated.
#    - Once todos exist, render the existing `BuildProgress` component inline (no tabs). Preserve build history/element change sections below.
#
# 4. **Cleanup & Polish**
#    - Remove unused state (chat history toggles, raw log toggles, etc.) and related helpers.
#    - Verify empty-state behavior still works when no request/plan/todos exist.
